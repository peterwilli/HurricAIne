# %%
from pandas import read_csv
import pandas as pd
from datetime import datetime
from geopy.distance import great_circle

def clean_html(df):
    df.replace({r'<.*?>': ''}, regex=True, inplace=True)

# %% [markdown]
# ## Bejing Pollution Data Preparation

# %%
# load data
def parse(x):
	return datetime.strptime(x, '%Y %m %d %H')
dataset = read_csv('HurricaneData/PRSA_data_2010.1.1-2014.12.31.csv',  parse_dates = [['year', 'month', 'day', 'hour']], index_col=0, date_parser=parse)
dataset.drop('No', axis=1, inplace=True)
# manually specify column names
dataset.columns = ['pollution', 'dew', 'temp', 'press', 'wnd_dir', 'wnd_spd', 'snow', 'rain']
dataset.index.name = 'date'
# mark all NA values with 0
dataset['pollution'].fillna(0, inplace=True)
# drop the first 24 hours
dataset = dataset[24:]
# summarize first 5 rows
print(dataset.head(5))
# save to file
dataset.to_csv('HurricaneData/Preprocessed/pollution.csv')

# %% [markdown]
# # Texas, Houston weather data

# %%
def parse(x):
	return datetime.strptime(x, '%Y-%m-%d')
dataset = read_csv('HurricaneData/houston.csv', index_col=0)
print("Original dataset:")
print(dataset.head(5))
dataset.set_index(dataset['Date'], inplace=True)
dataset.index = pd.to_datetime(dataset.index)
dataset.drop(dataset.columns[0], axis=1, inplace=True)

# mark all NA values with 0
dataset.fillna(0, inplace=True)

clean_html(dataset)

# summarize first 5 rows
print("Processed dataset:")
print(dataset.head(5))
# save to file
dataset.to_csv('HurricaneData/Preprocessed/houston.csv')
# Out:
# Original dataset:
#          Date  Max.TemperatureF  Mean.TemperatureF  Min.TemperatureF  \
# 1  1948-06-30               NaN                NaN               NaN
# 2  1948-07-01              90.0               80.0              69.0
# 3  1948-07-02              87.0               80.0              73.0
# 4  1948-07-03              84.0               80.0              75.0
# 5  1948-07-04              88.0               80.0              73.0
#
#    Max.Dew.PointF  MeanDew.PointF  Min.DewpointF  Max.Humidity  Mean.Humidity  \
# 1             NaN             NaN            NaN           NaN            NaN
# 2            74.0            70.0           67.0         100.0           76.0
# 3            76.0            74.0           71.0          97.0           84.0
# 4            79.0            75.0           70.0         100.0           86.0
# 5            77.0            75.0           73.0          97.0           83.0
#
#    Min.Humidity   ...    Min.VisibilityMiles  Max.Wind.SpeedMPH  \
# 1           NaN   ...                    NaN                NaN
# 2          52.0   ...                    3.0               23.0
# 3          67.0   ...                    3.0               14.0
# 4          67.0   ...                    3.0               10.0
# 5          61.0   ...                    0.0               12.0
#
#    Mean.Wind.SpeedMPH  Max.Gust.SpeedMPH  PrecipitationIn  CloudCover  \
# 1                 NaN                NaN             0.00         NaN
# 2                 7.0                NaN             0.00         0.0
# 3                 6.0                NaN             0.00         0.0
# 4                 5.0                NaN             0.00         0.0
# 5                 6.0                NaN             0.00         0.0
#
#                   Events  WindDirDegrees.br...          city  season
# 1                    NaN              -1<br />  Houston (TX)  Summer
# 2                    Fog              44<br />  Houston (TX)  Summer
# 3  Fog-Rain-Thunderstorm              84<br />  Houston (TX)  Summer
# 4               Fog-Rain              69<br />  Houston (TX)  Summer
# 5  Fog-Rain-Thunderstorm              84<br />  Houston (TX)  Summer
#
# [5 rows x 25 columns]
# Processed dataset:
#             Max.TemperatureF  Mean.TemperatureF  Min.TemperatureF  \
# Date
# 1948-06-30               0.0                0.0               0.0
# 1948-07-01              90.0               80.0              69.0
# 1948-07-02              87.0               80.0              73.0
# 1948-07-03              84.0               80.0              75.0
# 1948-07-04              88.0               80.0              73.0
#
#             Max.Dew.PointF  MeanDew.PointF  Min.DewpointF  Max.Humidity  \
# Date
# 1948-06-30             0.0             0.0            0.0           0.0
# 1948-07-01            74.0            70.0           67.0         100.0
# 1948-07-02            76.0            74.0           71.0          97.0
# 1948-07-03            79.0            75.0           70.0         100.0
# 1948-07-04            77.0            75.0           73.0          97.0
#
#             Mean.Humidity  Min.Humidity  Max.Sea.Level.PressureIn   ...    \
# Date                                                                ...
# 1948-06-30            0.0           0.0                      0.00   ...
# 1948-07-01           76.0          52.0                     30.11   ...
# 1948-07-02           84.0          67.0                     30.12   ...
# 1948-07-03           86.0          67.0                     30.08   ...
# 1948-07-04           83.0          61.0                     30.05   ...
#
#             Min.VisibilityMiles  Max.Wind.SpeedMPH  Mean.Wind.SpeedMPH  \
# Date
# 1948-06-30                  0.0                0.0                 0.0
# 1948-07-01                  3.0               23.0                 7.0
# 1948-07-02                  3.0               14.0                 6.0
# 1948-07-03                  3.0               10.0                 5.0
# 1948-07-04                  0.0               12.0                 6.0
#
#             Max.Gust.SpeedMPH  PrecipitationIn  CloudCover  \
# Date
# 1948-06-30                0.0             0.00         0.0
# 1948-07-01                0.0             0.00         0.0
# 1948-07-02                0.0             0.00         0.0
# 1948-07-03                0.0             0.00         0.0
# 1948-07-04                0.0             0.00         0.0
#
#                            Events  WindDirDegrees.br...          city  season
# Date
# 1948-06-30                      0                    -1  Houston (TX)  Summer
# 1948-07-01                    Fog                    44  Houston (TX)  Summer
# 1948-07-02  Fog-Rain-Thunderstorm                    84  Houston (TX)  Summer
# 1948-07-03               Fog-Rain                    69  Houston (TX)  Summer
# 1948-07-04  Fog-Rain-Thunderstorm                    84  Houston (TX)  Summer
#
# [5 rows x 24 columns]

# %%
houston_lat_lon = (29.76043, -95.36980)

def location_filter(x):
    distance = great_circle((x['Latitude'], x['Longitude']), houston_lat_lon).miles
    return distance < 700
    
def parse_date(x):
    split = x.split(" ")
    return datetime.strptime("%s %s" % (split[0], split[1].zfill(4)), '%Y%m%d %H%M')
    
dataset = read_csv('HurricaneData/atlantic.csv', parse_dates=[['Date', 'Time']], date_parser=parse_date, index_col=0)
print("Original dataset:")
print(dataset.head(5))
dataset.drop(dataset.columns[0], axis=1, inplace=True)
dataset.index.name = 'Date'
dataset.index = pd.to_datetime(dataset.index)

dataset['Latitude'].replace({r'[^0-9]': ''}, regex=True, inplace=True)
dataset['Longitude'].replace({r'[^0-9]': ''}, regex=True, inplace=True)
dataset['Latitude'] = pd.to_numeric(dataset['Latitude'], downcast='float')
dataset['Longitude'] = pd.to_numeric(dataset['Longitude'], downcast='float')
dataset = dataset[dataset.apply(location_filter, axis=1)]
dataset.replace(-999, 0, inplace=True)
# summarize first 5 rows
print("Processed dataset:")
print(dataset.head(5))
# save to file
dataset.to_csv('HurricaneData/Preprocessed/hurdat_houston.csv')
# Out:
# Original dataset:
#                            ID                 Name Event Status Latitude  \
# Date_Time
# 1851-06-25 00:00:00  AL011851              UNNAMED           HU    28.0N
# 1851-06-25 06:00:00  AL011851              UNNAMED           HU    28.0N
# 1851-06-25 12:00:00  AL011851              UNNAMED           HU    28.0N
# 1851-06-25 18:00:00  AL011851              UNNAMED           HU    28.1N
# 1851-06-25 21:00:00  AL011851              UNNAMED     L     HU    28.2N
#
#                     Longitude  Maximum Wind  Minimum Pressure  Low Wind NE  \
# Date_Time
# 1851-06-25 00:00:00     94.8W            80              -999         -999
# 1851-06-25 06:00:00     95.4W            80              -999         -999
# 1851-06-25 12:00:00     96.0W            80              -999         -999
# 1851-06-25 18:00:00     96.5W            80              -999         -999
# 1851-06-25 21:00:00     96.8W            80              -999         -999
#
#                      Low Wind SE  Low Wind SW  Low Wind NW  Moderate Wind NE  \
# Date_Time
# 1851-06-25 00:00:00         -999         -999         -999              -999
# 1851-06-25 06:00:00         -999         -999         -999              -999
# 1851-06-25 12:00:00         -999         -999         -999              -999
# 1851-06-25 18:00:00         -999         -999         -999              -999
# 1851-06-25 21:00:00         -999         -999         -999              -999
#
#                      Moderate Wind SE  Moderate Wind SW  Moderate Wind NW  \
# Date_Time
# 1851-06-25 00:00:00              -999              -999              -999
# 1851-06-25 06:00:00              -999              -999              -999
# 1851-06-25 12:00:00              -999              -999              -999
# 1851-06-25 18:00:00              -999              -999              -999
# 1851-06-25 21:00:00              -999              -999              -999
#
#                      High Wind NE  High Wind SE  High Wind SW  High Wind NW
# Date_Time
# 1851-06-25 00:00:00          -999          -999          -999          -999
# 1851-06-25 06:00:00          -999          -999          -999          -999
# 1851-06-25 12:00:00          -999          -999          -999          -999
# 1851-06-25 18:00:00          -999          -999          -999          -999
# 1851-06-25 21:00:00          -999          -999          -999          -999
# Processed dataset:
#                                     Name Event Status  Latitude  Longitude  \
# Date
# 1853-09-09 00:00:00              UNNAMED           HU     390.0      623.0
# 1854-09-11 18:00:00              UNNAMED           HU     395.0      618.0
# 1856-09-03 00:00:00              UNNAMED           TS     382.0      618.0
# 1858-09-22 00:00:00              UNNAMED           HU     390.0      636.0
# 1859-07-01 12:00:00              UNNAMED           HU     215.0      975.0
#
#                      Maximum Wind  Minimum Pressure  Low Wind NE  Low Wind SE  \
# Date
# 1853-09-09 00:00:00           100                 0            0            0
# 1854-09-11 18:00:00            90                 0            0            0
# 1856-09-03 00:00:00            50                 0            0            0
# 1858-09-22 00:00:00            80                 0            0            0
# 1859-07-01 12:00:00            90                 0            0            0
#
#                      Low Wind SW  Low Wind NW  Moderate Wind NE  \
# Date
# 1853-09-09 00:00:00            0            0                 0
# 1854-09-11 18:00:00            0            0                 0
# 1856-09-03 00:00:00            0            0                 0
# 1858-09-22 00:00:00            0            0                 0
# 1859-07-01 12:00:00            0            0                 0
#
#                      Moderate Wind SE  Moderate Wind SW  Moderate Wind NW  \
# Date
# 1853-09-09 00:00:00                 0                 0                 0
# 1854-09-11 18:00:00                 0                 0                 0
# 1856-09-03 00:00:00                 0                 0                 0
# 1858-09-22 00:00:00                 0                 0                 0
# 1859-07-01 12:00:00                 0                 0                 0
#
#                      High Wind NE  High Wind SE  High Wind SW  High Wind NW
# Date
# 1853-09-09 00:00:00             0             0             0             0
# 1854-09-11 18:00:00             0             0             0             0
# 1856-09-03 00:00:00             0             0             0             0
# 1858-09-22 00:00:00             0             0             0             0
# 1859-07-01 12:00:00             0             0             0             0
